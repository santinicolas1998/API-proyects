# %% [markdown]
# <a href="https://colab.research.google.com/github/santinicolas1998/API-proyects/blob/main/API_BCRA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Credenciales

# %%
#Podrás obtener tus credenciales desde: https://api.matbarofex.com.ar/v2/register
#Si es la primera vez que accedés, luego de registrarte deberás mandar un mail a investigacion@matbarofex.com.ar para activar tu usuario


#Credenciales:
username = "zaxruiz98"
password = "Milanesa98_"

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/My Drive/Python data')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Token de autenticación

# %%
import requests
import pandas as pd

# Token proporcionado
token = "eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE3Njc3MTcwMTIsInR5cGUiOiJleHRlcm5hbCIsInVzZXIiOiJydWl6c2FudGlhZ29uaWNvbGFzN0BnbWFpbC5jb20ifQ.ZjyboyfZos7cj3WPO8vIc6A72E-e4BwtGXwa15GYaqYD5hpBwuQGUMELvFAlM5uHW3sXdsftRfKaiZIq-PBS_g"

# URL del endpoint (reemplazar con el endpoint específico de interés)
url = "https://api.estadisticasbcra.com/base"

# Encabezados con el token de autorización
headers = {
    "Authorization": f"BEARER {token}"
}

# Solicitud GET
response = requests.get(url, headers=headers)

# Verificar la respuesta
if response.status_code == 200:
    # Procesar la respuesta JSON
    data = response.json()
    print(data)
else:
    # Manejar errores
    print(f"Error: {response.status_code} - {response.text}")

df = pd.DataFrame(data)
df
# Out:
# [{'d': '1996-01-02', 'v': 13069}, {'d': '1996-01-03', 'v': 12970}, {'d': '1996-01-04', 'v': 13034}, {'d': '1996-01-05', 'v': 13097}, {'d': '1996-01-08', 'v': 13104}, {'d': '1996-01-09', 'v': 13011}, {'d': '1996-01-10', 'v': 12905}, {'d': '1996-01-11', 'v': 12848}, {'d': '1996-01-12', 'v': 12820}, {'d': '1996-01-15', 'v': 12772}, {'d': '1996-01-16', 'v': 12679}, {'d': '1996-01-17', 'v': 12548}, {'d': '1996-01-18', 'v': 12528}, {'d': '1996-01-19', 'v': 12454}, {'d': '1996-01-22', 'v': 12379}, {'d': '1996-01-23', 'v': 12262}, {'d': '1996-01-24', 'v': 12110}, {'d': '1996-01-25', 'v': 12053}, {'d': '1996-01-26', 'v': 11998}, {'d': '1996-01-29', 'v': 12058}, {'d': '1996-01-30', 'v': 12103}, {'d': '1996-01-31', 'v': 12209}, {'d': '1996-02-01', 'v': 12355}, {'d': '1996-02-02', 'v': 12485}, {'d': '1996-02-05', 'v': 12637}, {'d': '1996-02-06', 'v': 12687}, {'d': '1996-02-07', 'v': 12706}, {'d': '1996-02-08', 'v': 12739}, {'d': '1996-02-09', 'v': 12701}, {'d': '1996-02-12', 'v': 12606}, {'d': '1996-02-13', 'v': 12432}, {'d': '1996-02-14', 'v': 12320}, {'d': '1996-02-15', 'v': 12284}, {'d': '1996-02-16', 'v': 12220}, {'d': '1996-02-19', 'v': 12159}, {'d': '1996-02-20', 'v': 12081}, {'d': '1996-02-21', 'v': 11987}, {'d': '1996-02-22', 'v': 11928}, {'d': '1996-02-23', 'v': 11846}, {'d': '1996-02-26', 'v': 11828}, {'d': '1996-02-27', 'v': 11824}, {'d': '1996-02-28', 
#                d         v
# 0     1996-01-02     13069
# 1     1996-01-03     12970
# 2     1996-01-04     13034
# 3     1996-01-05     13097
# 4     1996-01-08     13104
# ...          ...       ...
# 6962  2024-03-26  11232990
# 6963  2024-03-27  12463695
# 6964  2024-04-03  11604677
# 6965  2024-04-04  11600629
# 6966  2024-04-05  11744788
#
# [6967 rows x 2 columns]

# %%
import requests
import pandas as pd

# URL del endpoint (reemplazar con el endpoint específico de interés)
url = "https://api.bcra.gob.ar/estadisticas/v3.0/monetarias"

# Solicitud GET
response = requests.get(url, verify=False)

# Verificar la respuesta
if response.status_code == 200:
    # Procesar la respuesta JSON
    data = response.json()
    print(data)
else:
    # Manejar errores
    print(f"Error: {response.status_code} - {response.text}")

df = pd.DataFrame(data)
df2 = df['results'].apply(pd.Series)
df2
# Out:
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.bcra.gob.ar'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# {'status': 200, 'results': [{'idVariable': 1, 'descripcion': 'Reservas Internacionales del BCRA\xa0(en millones de dólares - cifras provisorias sujetas a cambio de valuación)', 'categoria': 'Principales Variables', 'fecha': '2024-12-30', 'valor': 29612.0}, {'idVariable': 4, 'descripcion': 'Tipo de Cambio Minorista ($ por USD) Comunicación B 9791 - Promedio vendedor', 'categoria': 'Principales Variables', 'fecha': '2025-01-03', 'valor': 1062.8}, {'idVariable': 5, 'descripcion': 'Tipo de Cambio Mayorista ($ por USD) Comunicación A 3500\xa0- Referencia', 'categoria': 'Principales Variables', 'fecha': '2025-01-03', 'valor': 1034.75}, {'idVariable': 6, 'descripcion': 'Tasa de Política Monetaria (en % n.a.)', 'categoria': 'Principales Variables', 'fecha': '2025-01-03', 'valor': 32.0}, {'idVariable': 7, 'descripcion': 'BADLAR en pesos de bancos privados (en % n.a.)', 'categoria': 'Principales Variables', 'fecha': '2025-01-02', 'valor': 31.625}, {'idVariable': 8, 'descripcion': 'TM20 en pesos de bancos privados\xa0(en % n.a.)', 'categoria': 'Principales Variables', 'fecha': '2025-01-02', 'valor': 32.75}, {'idVariable': 9, 'descripcion': 'Tasas de interés de las operaciones de pase activas para el BCRA, a 1 día de plazo\xa0(en % n.a.)', 'categoria': 'Principales Variables', 'fecha': '2025-01-06', 'valor': 36.0}, {'idVariable': 10, 'descripcion': 'Tasas de interés de las operaciones de pase pasivas para el BCRA, a 1 día de plazo\xa0(en % n.a.)', 'categoria': 'Principales Variables', 'fecha': '2024-07-19', 'valor': 40.0}, {'idVariable': 11, 'descripcion': 'Tasas de interés por préstamos entre entidades financiera privadas (BAIBAR)\xa0(en % n.a.)', 'categoria': 'Principales Variables', 'fecha': '2025-01-02', 'valor': 38.04}, {'idVariable': 12, 'descripcion': 'Tasas de interés por depósitos a 30 días de plazo en entidades financieras\xa0(en % n.a.)', 'categoria': 'Principales Variables', 'fecha': '2025-01-02', 'valor': 31.42}, {'idVariable': 13, 'descripcion': 'Tasa de interés de préstamos por adelantos en cuenta corriente', 'categoria': 'Principales Variables', 'fecha': '2025-01-02', 'valor': 39.63}, {'idVariable': 14, 'descripcion': 'Tasa de interés de préstamos personales', 'categoria': 'Principales Variables', 'fecha': '2025-01-02', 'valor': 73.02}, {'idVariable': 15, 'descripcion': 'Base monetaria\xa0- Total (en millones de pesos)', 'categoria': 'Principales Variables', 'fecha': '2024-12-30', 'valor': 29728575.0}, {'idVariable': 16, 'descripcion': 'Circulación monetaria\xa0(en millones de pesos)', 'categoria': 'Principales Variables', 'fecha': '2024-12-30', 'valor': 19988275.0}, {'idVariable': 17, 'descripcion': 'Billetes y monedas en poder del público\xa0(en millones de pesos)', 'categoria': 'Principales Variables', 'fecha': '2024-12-30', 'valor': 17741647.0}, {'idVariable': 18, 'descripcion': 'Efectivo en entidades financieras\xa0(en millones de pesos)', 'categoria': 'Principales Variables', 'fecha': '2024-12-30', 'valor': 2246628.0}, {'idVariable': 19, 'descripcion': 'Depósitos de los bancos en cta. cte. en pesos en el BCRA\xa0(en millones de pesos)', 'categoria': 'Principales Variables', 'fecha': '2024-12-30', 'valor': 9740300.0}, {'idVariable': 21, 'descripcion': 'Depósitos en efectivo en las entidades financieras - Total (en millones de pesos)', 'categoria': 'Principales Variables', 'fecha': '2024-12-30', 'valor': 140205879.0}, {'idVariable': 22, 'descripcion': 'En cuentas corrientes (neto de utilización FUCO)\xa0(en millones de pesos)', 'categoria': 'Principales Variables', 'fecha': '2024-12-30', 'valor': 28771094.0}, {'idVariable': 23, 'descripcion': 'En Caja de ahorros\xa0(en millones de pesos)', 'categoria': 'Principales Variables', 'fecha': '2024-12-30', 'valor': 54604738.0}, {'idVariable': 24, 'descripcion': 'A plazo (incluye inversiones y excluye CEDROS)\xa0(en millones de pesos)', 'categoria': 'Principales Variables', 'fecha': '2024-12-30', 'valor': 48744202.0}, {'idVariable': 25, 'descripcion': 'M2 privado, promedio móv ...
#      idVariable                                        descripcion  \
# 0             1  Reservas Internacionales del BCRA (en millones...
# 1             4  Tipo de Cambio Minorista ($ por USD) Comunicac...
# 2             5  Tipo de Cambio Mayorista ($ por USD) Comunicac...
# 3             6             Tasa de Política Monetaria (en % n.a.)
# 4             7     BADLAR en pesos de bancos privados (en % n.a.)
# ..          ...                                                ...
# 183         192  Margen sobre Bancos Privados de NOBAC de 12 me...
# 184         193  Margen sobre BADLAR Total de NOBAC de 2 Años (...
# 185         194  Margen sobre BADLAR Bancos Privados de NOBAC d...
# 186         195  Margen sobre Tasa de Politica Monetaria de NOT...
# 187         196  Saldo de Letras Fiscales de Liquidez en carter...
#
#                  categoria       fecha         valor
# 0    Principales Variables  2024-12-30  2.961200e+04
# 1    Principales Variables  2025-01-03  1.062800e+03
# 2    Principales Variables  2025-01-03  1.034750e+03
# 3    Principales Variables  2025-01-03  3.200000e+01
# 4    Principales Variables  2025-01-02  3.162500e+01
# ..                     ...         ...           ...
# 183            Series.xlsm  2013-04-16 -2.679300e+00
# 184            Series.xlsm  2006-02-07  6.194000e+00
# 185            Series.xlsm  2011-10-11  8.600000e-01
# 186            Series.xlsm  2023-09-13  2.500000e+00
# 187            Series.xlsm  2025-01-02  9.437516e+06
#
# [188 rows x 5 columns]
